# %% [markdown]
# #### Databricks Notebook Basics
# - Explore Databricks Notebook Features

# %%
# %run "./Utils"

# %% [markdown]
# ##### Python Cell

# %%
reverse_string("spark framework")

# %%
is_prime(17)

# %% [markdown]
# ##### SQL cell

# %%
# %sql

select current_catalog()

# %%
# %sql
select current_database()

# %% [markdown]
# ##### Scala cell

# %%
# %scala

val name = "Raju"
println(s"Name: ${name.upperCase}")

# %% [markdown]
# ##### Execute an external notebook

# %%
print_current_db()
