# %%
# %fs help

# %%
# %fs ls /Volumes/workspace/default/data

# %%
# %fs mkdirs dbfs:/Volumes/workspace/default/data/demo1

# %%
# %fs mkdirs dbfs:/Volumes/workspace/default/data/demo2

# %%
# %fs ls dbfs:/Volumes/workspace/default/data/university/

# %%
# %fs cp dbfs:/Volumes/workspace/default/data/university/employee.csv dbfs:/Volumes/workspace/default/data/demo1

# %%
# %fs cp -r dbfs:/Volumes/workspace/default/data/university/original/ dbfs:/Volumes/workspace/default/data/demo1

# %%
# %fs cp -r dbfs:/Volumes/workspace/default/data/university/original/ dbfs:/Volumes/workspace/default/data/demo1/original

# %%
# %fs ls dbfs:/Volumes/workspace/default/data/demo1

# %%
# %fs mv dbfs:/Volumes/workspace/default/data/demo1/Student_Counceling_Information.csv dbfs:/Volumes/workspace/default/data/demo2

# %%
# %fs mv -r dbfs:/Volumes/workspace/default/data/demo1/original/ dbfs:/Volumes/workspace/default/data/demo2

# %%
# %fs ls dbfs:/Volumes/workspace/default/data/demo2

# %%
# %fs rm dbfs:/Volumes/workspace/default/data/demo2/Student_Counceling_Information.csv

# %%
# %fs rm dbfs:/Volumes/workspace/default/data/demo2/test/

# %%
# %fs rm -r dbfs:/Volumes/workspace/default/data/demo2

# %%
# %fs ls dbfs:/Volumes/workspace/default/data/demo1

# %%
# %fs head dbfs:/Volumes/workspace/default/data/demo1/department.csv

# %%
# %fs head dbfs:/Volumes/workspace/default/data/demo1/Student_Performance_Data.csv

# %%
# %fs rm -r dbfs:/Volumes/workspace/default/data/demo1
