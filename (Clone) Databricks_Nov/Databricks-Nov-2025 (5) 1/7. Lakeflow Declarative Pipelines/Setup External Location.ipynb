-- %% [markdown]
-- #### Setup external locations for the Pipeline

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS bookstore_landing
URL "abfss://bookstore-landing@demoykrucdemodbsa.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL `demoykrucdemodbsa_cred`);

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS bookstore
URL "abfss://bookstore@demoykrucdemodbsa.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL `demoykrucdemodbsa_cred`);
